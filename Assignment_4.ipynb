# %% [markdown]
# #Assignment 4
# Md. Adnan Karim(7002536) Ahmad Lamloum(7003029)

# %% [markdown]
# #Exercise 4.1
#
# a, b, c, d are added at the end of the file.

# %% [markdown]
# #1(e)
# Hidden and Output layer values are determined using Hi=(∑SUM xiwi)+bi formula.
#
# logistic function f (x) = L/(1+e^(−x))
#
#
# Results are:
#
# h1=x1×w1+x2×w2+b1
#
#                         h1=0.05×0.15+0.10×0.20+0.35
#                                     h1=0.3775
#
#                          f (h1) = L/(1+e^(−0.3775))
#                          H1= 0.593270
#
#
#  h2=x1×w3+x2×w4+b1
#
#                         h2=0.05×0.25+0.10×0.30+0.35
#                                     H2=0.3925
#
#                          f (h2) = L/(1+e^(−0.3925))
#                          H2= 0.596884
#
# y1=H1×w5+H2×w6+b2
#
#                         y1=0.593269992×0.40+0.596884378×0.45+0.60
#                                     y1=1.10590597
#
#                         f (y1) = L/(1+e^(−1.10590597))
#                          Y1= 0.751365
#
# y2=H1×w7+H2×w8+b2
#
#                         y2=0.593269992×0.50+0.596884378×0.55+0.60
#                                     y2=1.2249214
#
#                          f (y2) = L/(1+e^(−1.2249214))
#                          Y2= 0.772928
#
# H1: 0.593270 and H2: 0.596884
#
# Y1: 0.751365 and Y2: 0.772928

# %% [markdown]
# The mean square error has been determined by the following equation:
#
#                 Etotal=∑1/2(T-O)^2-----1;
#                 where T=target value & O=drived output
#
#                 Etotal = 1/2(0.01-0.751365)^2  +  1/2(0.99-0.772928)^2
#                 Etotal = 0.298371
#
# Total mean square error: 0.298371

# %% [markdown]
# Error at w5 is
#
#                   W5 = ∂Etotal/∂w5-----2
#
#                 ∂Etotal/∂w5 = (∂Etotal/∂Y1) x (∂Y1/∂y1) x (∂y1/∂w5)
#
# From equation 1, it is clear that we cannot partially differentiate it with respect to w5 because there is no any w5. We split equation one into multiple terms so that we can easily differentiate it with respect to w5 as;
#
#
#                ∂Etotal/∂Y1 = 2* ½(T1-Y1)^(2-1)-1+0
#                =-(T1-Y1)
#               = -(0.01-0.75136507)
#               =0.74136507-----3
#
#               Y1=1/1+e^(-y1)------4
#
#               ∂Y1/∂y1 = Y1 X (1-Y1)=0.75136507(1-0.75136507)=0.186815602-----5
#
# Putting value from equation 5 to derive y1;
#
#           ∂y1/∂w5=∂((H1 X w5)+(H2 X w6)+b2)/∂w5=0.593269992-------6
#
# Finally substituting values for,
#
#
#          ∂Etotal/∂w5= (∂Etotal/∂Y1) x (∂Y1/∂y1) x (∂y1/∂w5)
#
#          =0.74136507 x 0.186815602 x 0.593269992
#
#          =0.082167041
#
# now we calculate the new W5 value;
#
#          W5 = w5 – 0.5 x (∂Etotal/∂w5) = 0.35891648

# %%
import matplotlib.pyplot as plt 

import numpy
import numpy as np 
import math

import array as arr

weight = [[0.15, 0.20], 
           [0.25, 0.3]]
input = [[0.05],
         [0.1]]
biasA = [[0.35],
        [0.35]]
result=[[0],[0]]
# iterate through rows of X
for i in range(len(weight)):
   # iterate through columns of Y
   for j in range(len(input[0])):
       # iterate through rows of Y
       for k in range(len(input)):
           result[i][j] += weight[i][k] * input[k][j]


hidden=[[0],[0]]
# iterate through rows of X
for i in range(len(result)):
   # iterate through columns of Y
   for j in range(len(result[0])):
     hidden[i][j] += result[i][j] + biasA[i][j]

sig = [[0],[0]]
for a in range(len(hidden)):
  for b in range(len(hidden[0])):
    sig[a]+=1/(1 + np.exp(-hidden[a][b]))
print("H1: %f and H2: %f" %((sig[0]), (sig[1])))


weightb = [[.40,.45],[.50,.55]]
biasB = [[0.6],[0.6]]

resultb = [[0],[0]]

outlay = [[0],[0]]

# iterate through rows of X
for ii in range(len(weightb)):
   # iterate through columns of Y
   for jj in range(len(sig[0])):
       # iterate through rows of Y
       for kk in range(len(sig)):
           resultb[ii][jj] += weightb[ii][kk] * sig[kk][jj]




# iterate through rows of X
for ii in range(len(resultb)):
   # iterate through columns of Y
   for jj in range(len(resultb[0])):
     outlay[ii][jj] += resultb[ii][jj] + biasB[ii][jj]

sigb = [[0],[0]]
for aa in range(len(outlay)):
  for bb in range(len(outlay[0])):
    sigb[aa]+=1/(1 + np.exp(-outlay[aa][bb]))
print("Y1: %f and Y2: %f" %((sigb[0]), (sigb[1])))

t=[[0.01],[0.99]]

error = [[0],[0]]

for a in range(len(t)):
  for b in range(len(t[0])):
    error[a][b] += 0.5*((t[a][b]-sigb[a][b])**2)

total=numpy.sum(error)

print("Total mean square error: %f" % total)

#∂Etotal/∂outy1 
eq3 = -(t[0]-sigb[0])

#∂outy1/∂y1
eq5 = sigb[0]*(1-sigb[0])

#∂y1/∂w5
eq6 = sig[0]/0.45

#∂Etotal/∂w5= (∂Etotal/∂outy1) x (∂outy1/∂y1) x (∂y1/∂w5)
eq2 = eq3*eq5*eq6

new_W5 = 0.45-(0.5*eq2)



print('new value for w5: %f' % new_W5)
# Out:
# H1: 0.593270 and H2: 0.596884
# Y1: 0.751365 and Y2: 0.772928
# Total mean square error: 0.298371
# new value for w5: 0.358703

# %% [markdown]
# #Exercise 4.2

# %%
import pandas as pd
import csv
from google.colab import files
def getLocalFiles():
    _files = files.upload()
    if len(_files) >0:
       for k,v in _files.items():
         open(k,'wb').write(v)
getLocalFiles()
# Out:
#      <input type="file" id="files-99817069-e029-42b2-9360-805737a84f5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99817069-e029-42b2-9360-805737a84f5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving red-wine.csv to red-wine.csv
# Saving white-wine.csv to white-wine.csv

# %%
import pandas as pd
red = pd.read_csv("red-wine.csv", sep=";")


white = pd.read_csv("white-wine.csv", sep=";")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot
import numpy as np

def qqplot(x, y, quantiles=None, interpolation='nearest', ax=None, rug=False,
           rug_length=0.05, rug_kwargs=None, **kwargs):
  # Get current axes if none are provided
    if ax is None:
        ax = plt.gca()

    if quantiles is None:
        quantiles = min(len(x), len(y))

    # Compute quantiles of the two samples
    if isinstance(quantiles, numbers.Integral):
        quantiles = np.linspace(start=0, stop=1, num=int(quantiles))
    else:
        quantiles = np.atleast_1d(np.sort(quantiles))
    x_quantiles = np.quantile(x, quantiles, interpolation=interpolation)
    y_quantiles = np.quantile(y, quantiles, interpolation=interpolation)

    # Draw the rug plots if requested
    if rug:
        # Default rug plot settings
        rug_x_params = dict(ymin=0, ymax=rug_length, c='gray', alpha=0.5)
        rug_y_params = dict(xmin=0, xmax=rug_length, c='gray', alpha=0.5)

        # Override default setting by any user-specified settings
        if rug_kwargs is not None:
            rug_x_params.update(rug_kwargs)
            rug_y_params.update(rug_kwargs)

        # Draw the rug plots
        for point in x:
          ax.axvline(point, **rug_x_params)
        for point in y:
            ax.axhline(point, **rug_y_params)

    # Draw the q-q plot
    ax.scatter(x_quantiles, y_quantiles, **kwargs)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# #(a)
# Here we plotted the "sulphates" quantity of both wine against "quality" by using Quantile-Quantile Method. Red wine seems to possess sulphate quantity two times higher than white wine. The quantity of sulphate increases with quality. However, correlation co-efficient Sulphates-Quality of wine is not clear.

# %%
import numbers
rwine=red['sulphates']
wwine=white['sulphates']

qr=red['quality']
qw=white['quality']

plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
qqplot(qr, rwine, c='r', alpha=0.5, edgecolor='k')
plt.xlabel('Quality')
plt.ylabel('Sulphates')
plt.title('Dependency between quality and sulphates of red wine (QQ-Plot)')


plt.subplot(1,2,2)
qqplot(qw, wwine, c='r', alpha=0.5, edgecolor='k')
plt.xlabel('Quality')
plt.ylabel('Sulphates')
plt.title('Dependency between quality and sulphates of white wine (QQ-Plot)')
plt.show()
plt.close()

# %% [markdown]
# #(b)
# A correlation matrix is a table exhibiting correlation coefficients between variables. Each cell in the table exhibits the correlation between two variables. A correlation matrix is used to summarize data, as an input into a more advanced analysis, and as a diagnostic for advanced analyses.
#
# Importance:
# A correlation matrix between two variables indicates that as one the value of one variable changes, the other variable tends to change in a specific direction. Understanding that relationship between variables is useful because we can use the value of one variable to predict the value of the other variable.
#
# Interpretation from correaltion matrix of "red" and "white" wine.
#
# The first table shows the correlation matrix of the variables of "red" wine dataset. The second table is the correlation matrix of "white" wine dataset. Red wine has the highest coefficient value of 0.67 (relationship between fixed acidity-citric acid, fixed acidity-density and free and total sulfer di-oxide). "White" wine has the highest correlation coefficient between density and residual sugar (0.84) suggesting strongest correlation.
#
# Red wine has higher correlation between sulphates-quality (0.25) compared to white wine (0.05).
#
# Correlation co-efficient also shows both wine dataset has distinct difference in different features. Some features show close correlation in both datasets (total and free sulfur dioxide, alcohol-quality).
#
# So, it can be concluded that the coefficient can be used as a good classifier.

# %%
corr = red.corr()
corr.style.background_gradient(cmap='coolwarm', axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col1 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col2 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col3 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col4 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_78a98876_bc2c_11ea_8f35_0242ac1c0002row0_col6 {
#             background-color:  #abc8fd;
#             color:  #000000;
# ...

# %%
corr = white.corr()

corr.style.background_gradient(cmap='coolwarm', axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col3 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col4 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_8c21e6d2_bc2c_11ea_8f35_0242ac1c0002row0_col6 {
#             background-color:  #b3cdfb;
#             color:  #000000;
# ...

# %% [markdown]
# #(c)

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from numpy import loadtxt
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import KFold

# %%
import numpy as np
#adding new column for 'class'
red_n = red
red_n['class'] = 1
white_n = white
white_n['class'] = 0 
#concatenate two datasets
df_new = pd.concat([red_n, white_n])


df_new.to_csv('file.csv', header=False, index=False)

tex = loadtxt("file.csv", delimiter=",")

# create scaler
scaler = StandardScaler()
x_raw = tex[:,0:12]
x =scaler.fit_transform(x_raw)
y = tex[:,12]

# %%
import numpy
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
cvscores=[]
# prepare cross validation
kfold = KFold(5, True, 1)
# enumerate splits
for train1, test1 in kfold.split(x, y):
	# define model
	model = Sequential()
	model.add(Dense(8, input_dim=12, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# fit model
	model.fit(x[train1], y[train1], epochs=150, batch_size=10, verbose=0)
	# evaluate the model
	scores = model.evaluate(x[test1], y[test1], verbose=0)
	print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
	cvscores.append(scores[1] * 100)


print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores))) 
# predict probabilities for test set
yhat_probs = model.predict(x[test1], verbose=0)
# predict crisp classes for test set
yhat_classes = model.predict_classes(x[test1], verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]
 

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y[test1], yhat_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(y[test1], yhat_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y[test1], yhat_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y[test1], yhat_classes)
print('F1 score: %f' % f1)
# Out:
# accuracy: 99.38%
# accuracy: 99.54%
# accuracy: 99.77%
# accuracy: 99.54%
# accuracy: 99.54%
# 99.55% (+/- 0.12%)
# Accuracy: 0.995381
# Precision: 0.993399
# Recall: 0.986885
# F1 score: 0.990132

# %% [markdown]
# (d)Here we performed principle component analysis of our standardized data to improve model of the neural network. The outcome shows a consistent F1 score, precission and recall score. Training datasets over principle components has significantly enhanced the accuracy, precision, recall and F1-score of our model.

# %%
from sklearn.decomposition import PCA
pca = PCA()
x_pca = pca.fit_transform(nor_x)
kfold = KFold(5, True, 1)
# enumerate splits
for train2, test2 in kfold.split(x_pca, y):
	# define model
	model = Sequential()
	model.add(Dense(8, input_dim=12, activation='relu'))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
	# fit model
	model.fit(x_pca[train2], y[train2], epochs=150, batch_size=10, verbose=0)



# predict probabilities for test set
yhat_probs2 = model.predict(x_pca[test2], verbose=0)
# predict crisp classes for test set
yhat_classes2 = model.predict_classes(x_pca[test2], verbose=0)
# reduce to 1d array
yhat_probs2 = yhat_probs2[:, 0]
yhat_classes2 = yhat_classes2[:, 0]

# accuracy: (tp + tn) / (p + n)
accuracy2 = accuracy_score(y[test2], yhat_classes2)
print('Accuracy: %f' % accuracy2)
# precision tp / (tp + fp)
precision2 = precision_score(y[test2], yhat_classes2)
print('Precision: %f' % precision2)
# recall: tp / (tp + fn)
recall2 = recall_score(y[test2], yhat_classes2)
print('Recall: %f' % recall2)
# f1: 2 tp / (2 tp + fp + fn)
f1_2 = f1_score(y[test2], yhat_classes2)
print('F1 score: %f' % f1_2)
# Out:
# Accuracy: 0.996151
# Precision: 0.993421
# Recall: 0.990164
# F1 score: 0.991790
